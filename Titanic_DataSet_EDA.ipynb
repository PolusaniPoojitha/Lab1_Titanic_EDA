# %%
import pandas as pa
# %pylab inline
df= pa.read_csv("D:\Poojitha\Data_Science_Essentials\Week_2\\train.csv")
df
# Out:
# Populating the interactive namespace from numpy and matplotlib
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# ...

# %% [markdown]
# <li> For PassengerId

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.PassengerId.hist()

# %% [markdown]
# <li> For Survived

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Survived.value_counts().plot(kind='bar')

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# <li> For PClass

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# <li> For Sex

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# <li> For Age

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 27.00    18
# 35.00    18
# 26.00    18
# 32.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 20.00    15
# 34.00    15
# 33.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 48.00     9
#          ..
# 0.75      2
# 45.50     2
# 64.00     2
# 30.50     2
# 0.83      2
# 32.50     2
# 40.50     2
# 71.00     2
# 28.50     2
# 63.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 70.00     2
# 55.50     1
# 24.50     1
# 34.50     1
# 0.92      1
# 36.50     1
# 0.42      1
# 23.50     1
# 12.00     1
# 20.50     1
# 14.50     1
# 80.00     1
# 74.00     1
# 70.50     1
# 66.00     1
# 53.00     1
# 0.67      1
# Name: Age, dtype: int64

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.hist()

# %% [markdown]
# <li> For SibSp

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.value_counts().plot(kind='bar')

# %% [markdown]
# <li> For Parch

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.value_counts().plot(kind='bar')

# %% [markdown]
# <li> For Ticket

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343           7
# 1601               7
# 347082             7
# 347088             6
# 3101295            6
# CA 2144            6
# 382652             5
# S.O.C. 14879       5
# 113781             4
# 349909             4
# 2666               4
# 19950              4
# 4133               4
# PC 17757           4
# W./C. 6608         4
# 113760             4
# 17421              4
# 347077             4
# LINE               4
# C.A. 34651         3
# 110413             3
# 35273              3
# C.A. 31921         3
# PC 17760           3
# F.C.C. 13529       3
# PC 17582           3
# 230080             3
# 239853             3
# PC 17755           3
# 371110             3
#                   ..
# 17764              1
# 2694               1
# 28424              1
# C 4001             1
# PC 17482           1
# 330958             1
# 113056             1
# 228414             1
# 349231             1
# 367228             1
# 334912             1
# 113051             1
# ...

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Ticket.value_counts().plot(kind='bar')

# %% [markdown]
# <li>For Fare

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 7.2292      15
# 0.0000      15
# 7.2500      13
# 7.8542      13
# 8.6625      13
# 7.2250      12
# 9.5000       9
# 16.1000      9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 14.5000      7
# 7.0500       7
# 52.0000      7
# 31.2750      7
# 69.5500      7
# 14.4542      7
# 7.7958       6
# 26.2500      6
# 30.0000      6
# 27.9000      6
#             ..
# 211.5000     1
# 12.2750      1
# 8.6542       1
# 6.9500       1
# 22.0250      1
# 7.1417       1
# 10.1708      1
# 17.4000      1
# 8.3000       1
# 16.0000      1
# 10.5167      1
# 15.0458      1
# 50.4958      1
# 8.4042       1
# 26.2833      1
# 12.6500      1
# 8.7125       1
# 22.5250      1
# 15.7500      1
# 9.2167       1
# 21.6792      1
# 14.1083      1
# 15.1000      1
# 7.3125       1
# 8.1125       1
# 13.8583      1
# 34.6542      1
# ...

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.hist()

# %% [markdown]
# <li> For Cabin

# %%
df.Cabin.value_counts()
# Out:
# G6                 4
# C23 C25 C27        4
# B96 B98            4
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# D                  3
# C52                2
# E33                2
# C126               2
# B35                2
# C68                2
# B20                2
# D35                2
# F4                 2
# E67                2
# B49                2
# C65                2
# E8                 2
# B51 B53 B55        2
# D17                2
# B57 B59 B63 B66    2
# D36                2
# B18                2
# E24                2
# C125               2
# B58 B60            2
# C93                2
# C124               2
#                   ..
# B69                1
# D50                1
# E38                1
# A6                 1
# D37                1
# C50                1
# C90                1
# C95                1
# B19                1
# C7                 1
# D28                1
# B39                1
# ...

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df.Cabin.value_counts().plot(kind='bar')

# %% [markdown]
# <li> For Embarked

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.value_counts().plot(kind='bar')

# %% [markdown]
# <li> Minimum, Maximum, Mean and SD of all the variables

# %%
df.describe()
# Out:
# C:\Users\Poojitha\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %% [markdown]
# <li> To Check whether there was priority given to Higher Class Passengers during rescuing.

# %%
df[(df.Pclass==1)].Survived.value_counts().plot(kind='bar')

# %%
df[(df.Pclass==2)].Survived.value_counts().plot(kind='bar')

# %%
df[(df.Pclass==3)].Survived.value_counts().plot(kind='bar')

# %% [markdown]
# <li> By the above figures we can conclude that there was clear prejudice in deciding a person's life based on their Class!
